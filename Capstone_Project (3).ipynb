# %%
import pandas as pd
a=pd.read_csv('/content/kidney_disease.csv')
print(a)
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0       0    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0       0    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 26 columns]

# %%
#1.preprocessing
a.isnull()
# Out:
#         id    age     bp     sg     al     su    rbc     pc    pcc     ba  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  False  False  False  False  False  False  False  False  False  False
# 396  False  False  False  False  False  False  False  False  False  False
# 397  False  False  False  False  False  False  False  False  False  False
# 398  False  False  False  False  False  False  False  False  False  False
# 399  False  False  False  False  False  False  False  False  False  False
#
#      ...    pcv     wc     rc    htn     dm    cad  appet     pe    ane  \
# 0    ...  False  False  False  False  False  False  False  False  False
# 1    ...  False  False   True  False  False  False  False  False  False
# 2    ...  False  False   True  False  False  False  False  False  False
# 3    ...  False  False  False  False  False  False  False  False  False
# 4    ...  False  False  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  ...  False  False  False  False  False  False  False  False  False
# 396  ...  False  False  False  False  False  False  False  False  False
# 397  ...  False  False  False  False  False  False  False  False  False
# 398  ...  False  False  False  False  False  False  False  False  False
# 399  ...  False  False  False  False  False  False  False  False  False
#
#      classification
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 395           False
# 396           False
# 397           False
# 398           False
# 399           False
#
# [400 rows x 26 columns]

# %%
b=a.fillna(0)
a=b
print(a)
a.isnull()
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0       0    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0       0    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000    0   no   no   no  good   no   no
# 2    notpresent  ...   31  7500    0   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 26 columns]
#         id    age     bp     sg     al     su    rbc     pc    pcc     ba  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  False  False  False  False  False  False  False  False  False  False
# 396  False  False  False  False  False  False  False  False  False  False
# 397  False  False  False  False  False  False  False  False  False  False
# 398  False  False  False  False  False  False  False  False  False  False
# 399  False  False  False  False  False  False  False  False  False  False
#
#      ...    pcv     wc     rc    htn     dm    cad  appet     pe    ane  \
# 0    ...  False  False  False  False  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False  False
# 2    ...  False  False  False  False  False  False  False  False  False
# 3    ...  False  False  False  False  False  False  False  False  False
# 4    ...  False  False  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  ...  False  False  False  False  False  False  False  False  False
# 396  ...  False  False  False  False  False  False  False  False  False
# 397  ...  False  False  False  False  False  False  False  False  False
# 398  ...  False  False  False  False  False  False  False  False  False
# 399  ...  False  False  False  False  False  False  False  False  False
#
#      classification
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 395           False
# 396           False
# 397           False
# 398           False
# 399           False
#
# [400 rows x 26 columns]

# %%
a=b.drop(columns=['id','su','al','pcv','wc','rc','dm','cad'])
print(a)
# Out:
#       age    bp     sg     rbc        pc         pcc          ba    bgr    bu  \
# 0    48.0  80.0  1.020       0    normal  notpresent  notpresent  121.0  36.0
# 1     7.0  50.0  1.020       0    normal  notpresent  notpresent    0.0  18.0
# 2    62.0  80.0  1.010  normal    normal  notpresent  notpresent  423.0  53.0
# 3    48.0  70.0  1.005  normal  abnormal     present  notpresent  117.0  56.0
# 4    51.0  80.0  1.010  normal    normal  notpresent  notpresent  106.0  26.0
# ..    ...   ...    ...     ...       ...         ...         ...    ...   ...
# 395  55.0  80.0  1.020  normal    normal  notpresent  notpresent  140.0  49.0
# 396  42.0  70.0  1.025  normal    normal  notpresent  notpresent   75.0  31.0
# 397  12.0  80.0  1.020  normal    normal  notpresent  notpresent  100.0  26.0
# 398  17.0  60.0  1.025  normal    normal  notpresent  notpresent  114.0  50.0
# 399  58.0  80.0  1.025  normal    normal  notpresent  notpresent  131.0  18.0
#
#       sc    sod  pot  hemo  htn appet   pe  ane classification
# 0    1.2    0.0  0.0  15.4  yes  good   no   no            ckd
# 1    0.8    0.0  0.0  11.3   no  good   no   no            ckd
# 2    1.8    0.0  0.0   9.6   no  poor   no  yes            ckd
# 3    3.8  111.0  2.5  11.2  yes  poor  yes  yes            ckd
# 4    1.4    0.0  0.0  11.6   no  good   no   no            ckd
# ..   ...    ...  ...   ...  ...   ...  ...  ...            ...
# 395  0.5  150.0  4.9  15.7   no  good   no   no         notckd
# 396  1.2  141.0  3.5  16.5   no  good   no   no         notckd
# 397  0.6  137.0  4.4  15.8   no  good   no   no         notckd
# 398  1.0  135.0  4.9  14.2   no  good   no   no         notckd
# 399  1.1  141.0  3.5  15.8   no  good   no   no         notckd
#
# [400 rows x 18 columns]

# %%
#Here the names/label for each column is not user friendly so giving column names user-friendly
a.columns = ['age', 'blood_pressure', 'specific_gravity', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin','hypertension', 'appetite', 'peda_edema',
              'anemia', 'class']

# %%
a.head(3)
# Out:
#     age  blood_pressure  specific_gravity red_blood_cells pus_cell  \
# 0  48.0            80.0              1.02               0   normal
# 1   7.0            50.0              1.02               0   normal
# 2  62.0            80.0              1.01          normal   normal
#
#   pus_cell_clumps    bacteria  blood_glucose_random  blood_urea  \
# 0      notpresent  notpresent                 121.0        36.0
# 1      notpresent  notpresent                   0.0        18.0
# 2      notpresent  notpresent                 423.0        53.0
#
#    serum_creatinine  sodium  potassium  haemoglobin hypertension appetite  \
# 0               1.2     0.0        0.0         15.4          yes     good
# 1               0.8     0.0        0.0         11.3           no     good
# 2               1.8     0.0        0.0          9.6           no     poor
#
#   peda_edema anemia class
# 0         no     no   ckd
# 1         no     no   ckd
# 2         no    yes   ckd

# %%
a.shape
# Out:
# (400, 18)

# %%
#a=a.drop(columns=["packed_cell_volume","white_blood_cell_count","red_blood_cell_count","diabetes_mellitus"])
#converting string values into numerical values
columns_replace=["red_blood_cells","pus_cell"]
columns_replace2=["pus_cell_clumps","bacteria"]
columns_replace3=["hypertension","peda_edema","anemia"]
a[columns_replace]=a[columns_replace].replace({"normal":1,"abnormal":0})
a[columns_replace2]=a[columns_replace2].replace({"present":1,"notpresent":0})
a[columns_replace3]=a[columns_replace3].replace({"yes":1,"no":0})
a["appetite"]=a["appetite"].replace({"good":1,"poor":0})
a["class"]=a["class"].replace({"ckd":1,"notckd":0,"ckd\t":1})
print(a)

#yes:1,no:0
#present:1,notpresent:0
#normal:1,abnormal:0
#good:1,poor:0
#ckd:1,notckd:0
# Out:
#       age  blood_pressure  specific_gravity red_blood_cells  pus_cell  \
# 0    48.0            80.0             1.020               0         1
# 1     7.0            50.0             1.020               0         1
# 2    62.0            80.0             1.010               1         1
# 3    48.0            70.0             1.005               1         0
# 4    51.0            80.0             1.010               1         1
# ..    ...             ...               ...             ...       ...
# 395  55.0            80.0             1.020               1         1
# 396  42.0            70.0             1.025               1         1
# 397  12.0            80.0             1.020               1         1
# 398  17.0            60.0             1.025               1         1
# 399  58.0            80.0             1.025               1         1
#
#      pus_cell_clumps  bacteria  blood_glucose_random  blood_urea  \
# 0                  0         0                 121.0        36.0
# 1                  0         0                   0.0        18.0
# 2                  0         0                 423.0        53.0
# 3                  1         0                 117.0        56.0
# 4                  0         0                 106.0        26.0
# ..               ...       ...                   ...         ...
# 395                0         0                 140.0        49.0
# 396                0         0                  75.0        31.0
# 397                0         0                 100.0        26.0
# 398                0         0                 114.0        50.0
# 399                0         0                 131.0        18.0
#
#      serum_creatinine  sodium  potassium  haemoglobin  hypertension  appetite  \
# 0                 1.2     0.0        0.0         15.4             1         1
# 1                 0.8     0.0        0.0         11.3             0         1
# 2                 1.8     0.0        0.0          9.6             0         0
# 3                 3.8   111.0        2.5         11.2             1         0
# 4                 1.4     0.0        0.0         11.6             0         1
# ..                ...     ...        ...          ...           ...       ...
# 395               0.5   150.0        4.9         15.7             0         1
# 396               1.2   141.0        3.5         16.5             0         1
# 397               0.6   137.0        4.4         15.8             0         1
# 398               1.0   135.0        4.9         14.2             0         1
# 399               1.1   141.0        3.5         15.8             0         1
#
#      peda_edema  anemia  class
# 0             0       0      1
# 1             0       0      1
# 2             0       1      1
# 3             1       1      1
# 4             0       0      1
# ..          ...     ...    ...
# 395           0       0      0
# 396           0       0      0
# 397           0       0      0
# 398           0       0      0
# 399           0       0      0
#
# [400 rows x 18 columns]

# %%
#a["packed_cell_volume"]=a["packed_cell_volume"].astype(float)
#a["white_blood_cell_count"]=a["white_blood_cell_count"].astype(float)
#a["red_blood_cell_count"]=a["red_blood_cell_count"].astype(float)
#a["diabetes_mellitus"]=a["diabetes_mellitus"].astype(float)
#print(a.dtypes)

a["red_blood_cells"]=a["red_blood_cells"].astype(float)
print(a.dtypes)
# Out:
# age                     float64
# blood_pressure          float64
# specific_gravity        float64
# red_blood_cells         float64
# pus_cell                  int64
# pus_cell_clumps           int64
# bacteria                  int64
# blood_glucose_random    float64
# blood_urea              float64
# serum_creatinine        float64
# sodium                  float64
# potassium               float64
# haemoglobin             float64
# hypertension              int64
# appetite                  int64
# peda_edema                int64
# anemia                    int64
# class                     int64
# dtype: object

# %%
#2.Identify features and target variables
features=a.drop(columns=["class"])
target=a["class"]
#print(features)
#print(target)

# %%
#3.Training and Testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.30)
print(x_train)
# Out:
#       age  blood_pressure  specific_gravity  red_blood_cells  pus_cell  \
# 132  50.0             0.0             0.000              1.0         0
# 365  24.0            80.0             1.020              1.0         1
# 360  35.0            60.0             1.025              1.0         1
# 92   71.0            70.0             1.010              1.0         0
# 279  24.0            70.0             1.025              1.0         1
# ..    ...             ...               ...              ...       ...
# 345  22.0            60.0             1.025              1.0         1
# 41   45.0            70.0             1.010              0.0         1
# 44   54.0            80.0             1.010              0.0         0
# 94   65.0            70.0             1.010              0.0         1
# 352  37.0            60.0             1.020              1.0         1
#
#      pus_cell_clumps  bacteria  blood_glucose_random  blood_urea  \
# 132                0         0                 219.0       176.0
# 365                0         0                  93.0        46.0
# 360                0         0                 105.0        39.0
# 92                 1         1                 219.0        82.0
# 279                0         0                 140.0        23.0
# ..               ...       ...                   ...         ...
# 345                0         0                  97.0        18.0
# 41                 0         0                   0.0        20.0
# 44                 0         0                 207.0        77.0
# 94                 0         0                  93.0        66.0
# 352                0         0                 109.0        47.0
#
#      serum_creatinine  sodium  potassium  haemoglobin  hypertension  appetite  \
# 132              13.8   136.0        4.5          8.6             1         1
# 365               1.0   145.0        3.5          0.0             0         1
# 360               0.5   135.0        3.9         14.7             0         1
# 92                3.6   133.0        4.4         10.4             1         1
# 279               0.6   140.0        4.7         16.3             0         1
# ..                ...     ...        ...          ...           ...       ...
# 345               1.2   138.0        4.3         13.5             0         1
# 41                0.7     0.0        0.0          0.0             0         1
# 44                6.3   134.0        4.8          9.7             1         0
# 94                1.6   137.0        4.5         11.6             0         1
# 352               1.1   141.0        4.9         15.0             0         1
#
#      peda_edema  anemia
# 132           1       1
# 365           0       0
# 360           0       0
# 92            0       0
# 279           0       0
# ..          ...     ...
# 345           0       0
# 41            1       0
# 44            1       0
# 94            0       0
# 352           0       0
#
# [280 rows x 17 columns]

# %%
#4.model
import math
import random
import numpy as np
log_error=[]
k=[]
def logistic_regression(w0,w1,w2,w3,w4,w5,w6,w7,w8,w9,w10,w11,w12,w13,w14,w15,w16,w17):
  c=0
  for i in range(len(x_train)):
    z0=x_train['age'].iloc[i]*w0   #z1=x_train['Age].iloc[:, :-1].values
    z1=x_train['blood_pressure'].iloc[i]*w1
    z2=x_train['specific_gravity'].iloc[i]*w2
    z3=x_train['red_blood_cells'].iloc[i]*w3
    z4=x_train['pus_cell'].iloc[i]*w4
    z5=x_train['pus_cell_clumps'].iloc[i]*w5
    z6=x_train['bacteria'].iloc[i]*w6
    z7=x_train['blood_glucose_random'].iloc[i]*w7
    z8=x_train['blood_urea'].iloc[i]*w8
    z9=x_train['serum_creatinine'].iloc[i]*w9
    z10=x_train['sodium'].iloc[i]*w10
    z11=x_train['potassium'].iloc[i]*w11
    z12=x_train['haemoglobin'].iloc[i]*w12
    z13=x_train['hypertension'].iloc[i]*w13
    z14=x_train['appetite'].iloc[i]*w14
    z15=x_train['peda_edema'].iloc[i]*w15
    z16=(x_train['anemia'].iloc[i]*w16)+w17

    z=z0+z1+z2+z3+z4+z5+z6+z7+z8+z9+z10+z11+z12+z13+z14+z15+z16
    Ypz=1/(1+math.exp(-z))
    Ypz=max(min(1,1-1e-15),1e-15)
    k.append(-y_train.iloc[i]*math.log(Ypz)-(1-y_train.iloc[i])*math.log(1-Ypz))
    if(Ypz>=0.5 and y_train.iloc[i]==1) or(Ypz<0.5 and y_train.iloc[i]==0):
      c+=1
    ac=c/len(x_train)
    return k,ac
w0=random.randint(1,10)
w1=random.randint(1,10)
w2=random.randint(1,10)
w3=random.randint(1,10)
w4=random.randint(1,10)
w5=random.randint(1,10)
w6=random.randint(1,10)
w7=random.randint(1,10)
w8=random.randint(1,10)
w9=random.randint(1,10)
w10=random.randint(1,10)
w11=random.randint(1,10)
w12=random.randint(1,10)
w13=random.randint(1,10)
w14=random.randint(1,10)
w15=random.randint(1,10)
w16=random.randint(1,10)
w17=random.randint(1,10)

k,ac=logistic_regression(w0,w1,w2,w3,w4,w5,w6,w7,w8,w9,w10,w11,w12,w13,w14,w15,w16,w17)
k=np.mean(k)
print(k)
print(ac)
# Out:
# 9.992007221626415e-16
# 0.0035714285714285713

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lg=LogisticRegression()
lg.fit(x_train,y_train)

#new_data = [[age,blood_pressure,specific_gravity,red_blood_cells,pus_cell,pus_cell_clumps,bacteria,blood_glucose_random,blood_urea,serum_creatinine,sodium,potassium,haemoglobin,hypertension,appetite,peda_edema,anemia]]  # Make sure it matches the feature dimensions

#new_data=[[17,120,1.0,1,0,1,0,0,277,6.95,137,5.98,9.5,0,1,0,0]] #yes->real data
#new_data=[[17,120,1.0,1,1,1,0,0,24,1.9,140,4.5,14.2,0,1,0,0]] #no->modified data
#new_data=[[17,60,1.025,1,1,0,0,114,50,1,135,4.9,14.2,0,1,0,0]] #from dataset->no
new_data=[[76,70,1.015,1,1,0,0,92,29,1.8,133,3.9,10.3,1,1,0,0]] #from dataset->yes
# Use the trained model to make predictions

y_p=lg.predict(x_test)
print("Accuracy:",accuracy_score(y_test,y_p))
#print("\n\n\n")
predictions = lg.predict(new_data)
print(predictions)
# Out:
# Accuracy: 0.9583333333333334
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Assuming you already have the following variables defined:
# x_train, x_test, y_train, y_test, lg (trained Logistic Regression model)

# Make predictions on the test set
y_pred = lg.predict(x_test)

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_test, y_pred)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

a=pd.read_csv("/content/kidney_disease.csv")

a.isnull()
b=a.fillna(0)
a=b

a.isnull()
a=b.drop(columns=['id','su','al','pcv','wc','rc','dm','cad'])

a.columns = ['age', 'blood_pressure', 'specific_gravity', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin','hypertension', 'appetite', 'peda_edema',
              'anemia', 'class']

columns_replace=["red_blood_cells","pus_cell"]
columns_replace2=["pus_cell_clumps","bacteria"]
columns_replace3=["hypertension","peda_edema","anemia"]
a[columns_replace]=a[columns_replace].replace({"normal":1,"abnormal":0})
a[columns_replace2]=a[columns_replace2].replace({"present":1,"notpresent":0})
a[columns_replace3]=a[columns_replace3].replace({"yes":1,"no":0})
a["appetite"]=a["appetite"].replace({"good":1,"poor":0})
a["class"]=a["class"].replace({"ckd":1,"notckd":0,"ckd\t":1})
a["red_blood_cells"]=a["red_blood_cells"].astype(float)

features=a.drop(columns=["class"])
target=a["class"]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.30)

# %%
#perceptron

sc = StandardScaler()
x_train_std = sc.fit_transform(x_train)
x_test_std = sc.transform(x_test)

perceptron = Perceptron()
perceptron.fit(x_train_std, y_train)

y_pred = perceptron.predict(x_test_std)

# accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 98.33%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

# Assuming you already have the following variables defined:
# x_train_std, x_test_std, y_train, y_test, perceptron (trained Perceptron model)

# Make predictions on the test set
y_pred = perceptron.predict(x_test_std)

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_test, y_pred)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
#svm

import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

sc =StandardScaler()
x_train_std=sc.fit_transform(x_train)
x_test_std=sc.transform(x_test)

svm=SVC(kernel='linear')
svm.fit(x_train_std,y_train)

y_pred=svm.predict(x_test_std)
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming you already have the following variables defined:
# x_train_std, x_test_std, y_train, y_test, svm (trained SVM model)

# Make predictions on the test set
y_pred = svm.predict(x_test_std)

# Generate the confusion matrix
confusion_mat = confusion_matrix(y_test, y_pred)

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 96.67%
